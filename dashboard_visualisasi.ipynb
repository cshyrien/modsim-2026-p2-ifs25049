# %% [markdown]
# ## Dashboard Visualisasi

# %%
import streamlit as st
import pandas as pd
import plotly.express as px

st.set_page_config(page_title="Dashboard Kuesioner", layout="wide")
st.title("📊 Dashboard Visualisasi Kuesioner")

# =====================
# LOAD DATA
# =====================
@st.cache_data
def load_data():
    return pd.read_excel("data_kuesioner.xlsx")

df = load_data()

# hapus kolom Partisipan
df_q = df.drop(columns=["Partisipan"])

# =====================
# MAPPING NILAI
# =====================
score_map = {
    "SS": 6,
    "S": 5,
    "CS": 4,
    "CTS": 3,
    "TS": 2,
    "STS": 1
}

sentimen_map = {
    "SS": "Positif",
    "S": "Positif",
    "CS": "Positif",
    "CTS": "Netral",
    "TS": "Negatif",
    "STS": "Negatif"
}

df_long = df_q.melt(
    var_name="Pertanyaan",
    value_name="Jawaban"
)

df_long["Skor"] = df_long["Jawaban"].map(score_map)
df_long["Kategori"] = df_long["Jawaban"].map(sentimen_map)

# =====================
# 1. BAR CHART DISTRIBUSI JAWABAN
# =====================
st.subheader("1️⃣ Distribusi Jawaban Keseluruhan")
fig1 = px.bar(
    df_long,
    x="Jawaban",
    category_orders={
        "Jawaban": ["SS", "S", "CS", "CTS", "TS", "STS"]
    },
    text_auto=True,
    title="Distribusi Jawaban Kuesioner"
)
st.plotly_chart(fig1, use_container_width=True)

# =====================
# 2. PIE CHART PROPORSI JAWABAN
# =====================
st.subheader("2️⃣ Proporsi Jawaban")
pie_data = df_long["Jawaban"].value_counts().reset_index()
pie_data.columns = ["Jawaban", "Jumlah"]

fig2 = px.pie(
    pie_data,
    names="Jawaban",
    values="Jumlah",
    title="Proporsi Jawaban Kuesioner"
)
st.plotly_chart(fig2, use_container_width=True)

# =====================
# 3. STACKED BAR PER PERTANYAAN
# =====================
st.subheader("3️⃣ Distribusi Jawaban per Pertanyaan")
stacked = (
    df_long
    .groupby(["Pertanyaan", "Jawaban"])
    .size()
    .reset_index(name="Jumlah")
)

fig3 = px.bar(
    stacked,
    x="Pertanyaan",
    y="Jumlah",
    color="Jawaban",
    barmode="stack",
    title="Distribusi Jawaban per Pertanyaan"
)
st.plotly_chart(fig3, use_container_width=True)

# =====================
# 4. RATA-RATA SKOR PER PERTANYAAN
# =====================
st.subheader("4️⃣ Rata-rata Skor per Pertanyaan")
mean_data = df_long.groupby("Pertanyaan")["Skor"].mean().reset_index()

fig4 = px.bar(
    mean_data,
    x="Pertanyaan",
    y="Skor",
    text_auto=".2f",
    title="Rata-rata Skor per Pertanyaan"
)
st.plotly_chart(fig4, use_container_width=True)

# =====================
# 5. DISTRIBUSI POSITIF / NETRAL / NEGATIF
# =====================
st.subheader("5️⃣ Distribusi Kategori Jawaban")
cat_data = df_long["Kategori"].value_counts().reset_index()
cat_data.columns = ["Kategori", "Jumlah"]

fig5 = px.bar(
    cat_data,
    x="Kategori",
    y="Jumlah",
    text_auto=True,
    title="Distribusi Jawaban Positif, Netral, dan Negatif"
)
st.plotly_chart(fig5, use_container_width=True)

# =====================
# BONUS: HEATMAP
# =====================
st.subheader("🎁 Bonus: Heatmap Rata-rata Skor")
heatmap_data = mean_data.set_index("Pertanyaan").T

fig6 = px.imshow(
    heatmap_data,
    text_auto=True,
    aspect="auto",
    title="Heatmap Rata-rata Skor Kuesioner"
)
st.plotly_chart(fig6, use_container_width=True)
# Out:
# 2026-02-16 18:35:44.754 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-16 18:35:44.757 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-16 18:35:44.758 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-16 18:35:44.759 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-16 18:35:44.762 No runtime found, using MemoryCacheStorageManager
# 2026-02-16 18:35:44.777 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-16 18:35:44.778 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-16 18:35:44.780 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-16 18:35:44.852 Please replace `use_container_width` with `width`.
#
# `use_container_width` will be removed after 2025-12-31.
#
# For `use_container_width=True`, use `width='stretch'`. For `use_container_width=False`, use `width='content'`.
# 2026-02-16 18:35:44.858 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-16 18:35:44.859 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-16 18:35:44.860 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-16 18:35:44.861 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-16 18:35:44.862 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-16 18:35:44.864 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-16 18:35:44.865 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-16 18:35:44.865 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-16 18:35:44.917 Please replace `use_container_width` with `width`.
#
# `use_container_width` will be removed after 2025-12-31.
#
# For `use_container_width=True`, use `width='stretch'`. For `use_container_width=False`, use `width='content'`.
# 2026-02-16 18:35:44.920 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-16 18:35:44.921 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-16 18:35:44.923 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-16 18:35:44.923 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-16 18:35:44.924 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-16 18:35:44.927 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-16 18:35:44.927 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-16 18:35:44.928 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-16 18:35:45.042 Please replace `use_container_width` with `width`.
#
# `use_container_width` will be removed after 2025-12-31.
#
# For `use_container_width=True`, use `width='stretch'`. For `use_container_width=False`, use `width='content'`.
# 2026-02-16 18:35:45.049 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-16 18:35:45.051 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-16 18:35:45.052 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-16 18:35:45.053 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-16 18:35:45.054 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-16 18:35:45.057 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-16 18:35:45.057 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-16 18:35:45.058 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-16 18:35:45.125 Please replace `use_container_width` with `width`.
#
# `use_container_width` will be removed after 2025-12-31.
#
# For `use_container_width=True`, use `width='stretch'`. For `use_container_width=False`, use `width='content'`.
# 2026-02-16 18:35:45.130 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-16 18:35:45.132 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-16 18:35:45.133 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-16 18:35:45.134 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-16 18:35:45.135 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-16 18:35:45.136 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-16 18:35:45.137 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-16 18:35:45.138 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-16 18:35:45.201 Please replace `use_container_width` with `width`.
#
# `use_container_width` will be removed after 2025-12-31.
#
# For `use_container_width=True`, use `width='stretch'`. For `use_container_width=False`, use `width='content'`.
# 2026-02-16 18:35:45.204 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-16 18:35:45.205 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-16 18:35:45.206 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-16 18:35:45.207 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-16 18:35:45.208 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-16 18:35:45.210 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-16 18:35:45.211 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-16 18:35:45.211 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-16 18:35:45.269 Please replace `use_container_width` with `width`.
#
# `use_container_width` will be removed after 2025-12-31.
#
# For `use_container_width=True`, use `width='stretch'`. For `use_container_width=False`, use `width='content'`.
# 2026-02-16 18:35:45.274 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-16 18:35:45.274 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-16 18:35:45.276 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-16 18:35:45.277 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-16 18:35:45.278 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# DeltaGenerator()
